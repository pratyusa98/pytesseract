# %%
! pip install --user pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Requirement already satisfied: Pillow in c:\users\dell\appdata\roaming\python\python37\site-packages (from pytesseract) (8.1.0)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py): started
#   Building wheel for pytesseract (setup.py): finished with status 'done'
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13945 sha256=f12fad87daf8cd91cd2a32ec5bcef14a370569b86012084c4f1dae3a5807d976
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\67\71\6c\7a8c5ca2e699752506999ae7baeb692e2b4fc6488c2cddcb22
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.7

# %%
import pytesseract
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Tesseract-OCR\tesseract'

# %%
filename='1.png'

print(pytesseract.image_to_string(Image.open(filename)))

pil_im = Image.open(filename, 'r')
imshow(np.asarray(pil_im))
# Out:
# I am curious about
# area-filling text
# rendering options
